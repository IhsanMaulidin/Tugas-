# %% [markdown]
# <a href="https://colab.research.google.com/github/IhsanMaulidin/Tugas-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading DataSet

# %%
url='/content/drive/MyDrive/Colab Notebooks/data0-SZL.csv'
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    953  915  989  957  942  945  964  967  951  958  ...  999.2  1008  999.3  \
# 0  951  927  984  961  943  948  965  974  952  960  ...   1002  1002   1011
# 1  949  934  981  961  943  945  966  971  954  962  ...   1006   999   1016
# 2  948  936  981  960  944  943  964  973  955  961  ...   1009   999   1012
# 3  950  935  983  960  948  944  960  970  953  960  ...   1009   999   1008
# 4  950  938  987  961  954  946  963  965  951  958  ...   1007   999   1010
#
#    1024  931  831  962.5  919  1211  952.1
# 0  1030  935  830    965  914  1204    950
# 1  1033  937  832    965  913  1175    947
# 2  1033  937  827    967  913  1134    947
# 3  1032  934  825    966  916  1084    949
# 4  1032  931  822    965  917  1039    949
#
# [5 rows x 160 columns]

# %% [markdown]
# Perhitungan Statistika

# %%
df.describe(include='all')
# Out:
#                953          915          989          957          942  \
# count  3599.000000  3599.000000  3599.000000  3599.000000  3599.000000
# mean    968.532370   960.045568   967.593220   962.974437   970.038622
# std      38.087937    35.910211    39.111912    39.208241    38.269399
# min     906.000000   901.000000   901.000000   904.000000   908.000000
# 25%     951.000000   944.000000   950.000000   945.000000   954.000000
# 50%     964.000000   956.000000   962.000000   958.000000   964.000000
# 75%     975.000000   966.000000   975.000000   968.000000   976.000000
# max    1260.000000  1235.000000  1248.000000  1243.000000  1286.000000
#
#                945          964          967          951          958  ...  \
# count  3599.000000  3599.000000  3599.000000  3599.000000  3599.000000  ...
# mean    952.537371   957.130870   969.465685   961.415671   964.845235  ...
# std      37.387380    38.383315    35.377153    36.023648    34.295996  ...
# ...

# %%
df.skew()
# Out:
# 953      4.540302
# 915      4.660723
# 989      4.216797
# 957      4.389730
# 942      4.596763
#            ...
# 831      1.189443
# 962.5    1.692218
# 919      1.389198
# 1211     2.184692
# 952.1    2.465102
# Length: 160, dtype: float64

# %%
mean = np.mean(df)

# Menghitung energi (momen kedua)
energy = np.mean((df - mean) ** 2)

print("Energi:", energy)
# Out:
# Energi: 953      1450.287852
# 915      1289.184920
# 989      1529.316609
# 957      1536.859030
# 942      1464.139937
#             ...
# 831      5267.982189
# 962.5    4289.299762
# 919      2107.282781
# 1211     8322.382832
# 952.1    8975.867435
# Length: 160, dtype: float64
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
# Membuat subplot
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
# Menentukan kolom untuk plot
columns_to_plot = df.columns[:6]

# Plotting
for i, ax in enumerate(axes.flatten()):
    if i < len(columns_to_plot):
        df[columns_to_plot[i]].plot(ax=ax, kind='hist', title=columns_to_plot[i])
    else:
        ax.axis('off')  # Menghilangkan subplot yang tidak digunakan

plt.tight_layout()
plt.show()

# %%
means = np.mean(df, axis=0)
stds = np.std(df, axis=0)

# Plot
plt.figure(figsize=(10, 6))
for i in range(0, 160, 10):
    plt.scatter(means[i:i+10], stds[i:i+10], label=f'Columns {i}-{i+9}')

plt.xlabel('Mean')
plt.ylabel('Standard Deviation')
plt.title('Scatter Plot: Mean vs Standard Deviation for every 10 columns')
plt.legend()
plt.grid(True)
plt.show()

# %%
skewness = np.nanmean((df - np.nanmean(df, axis=0))**3 / np.nanstd(df, axis=0)**3, axis=0)
median = np.nanmedian(df, axis=0)

# Plot
plt.figure(figsize=(10, 6))
for i in range(0, 160, 10):
    plt.scatter(skewness[i:i+10], median[i:i+10], label=f'Columns {i}-{i+9}')

plt.xlabel('Skewness')
plt.ylabel('Median')
plt.title('Scatter Plot: Skewness vs Median for every 10 columns')
plt.legend()
plt.grid(True)
plt.show()
